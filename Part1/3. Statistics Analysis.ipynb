# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  بخش سوم: تحلیل‌های آماری
# </font>
# </h1>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این بخش، به کمک دانش آماری می‌خواهیم به تعدادی از سوال‌ها پاسخ دهیم؛ برخی از سوالات برای درک و یافتن شهود از داده‌ها پرسیده شده است، برخی دیگر از سمت یک شخص خاص، و در انتها تعدادی فرضیه مطرح شده است که شما باید آن‌ها را اعتبارسنجی کنید.
#
# </font>
# </p>

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import sqlalchemy as db
from sqlalchemy import create_engine, select, Column, Integer, String, Float, MetaData, Table
from sqlalchemy.orm import sessionmaker
import os
import random
from scipy import stats
from sqlalchemy import func
from sqlalchemy import bindparam

# %%
USERNAME = 'root'
PASSWORD = 'YOUR PASSWORD'
HOST = '127.0.0.1'
PORT = 3306
DATABASE = 'database2'
engine = create_engine(f'mysql+pymysql://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}', echo=True)

# %%
Session = sessionmaker(bind=engine)
session = Session()
metadata = MetaData()

# %% [markdown]
# <h2 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آمار توصیفی
# </font>
# </h2>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سوال ۱
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ارتباط میان ارزش بازار (Market Cap) و حجم معاملاتی روزانه (Volume 24h) رمزارزها را بررسی نمایید. برای این کار می‌توانید Scatter Plot آن را رسم کنید.
# </font>
# </p>

# %%
Session = sessionmaker(bind=engine)
session = Session()
metadata = MetaData()
MainDB = Table('FinalMain', metadata, autoload_with=engine)
# Out:
# 2023-09-11 22:17:37,805 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-09-11 22:17:37,806 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 22:17:37,807 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-09-11 22:17:37,808 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 22:17:37,808 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-09-11 22:17:37,809 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 22:17:37,810 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 22:17:37,811 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `FinalMain`
# 2023-09-11 22:17:37,811 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 22:17:37,820 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
query = select((MainDB.c.Market_Cap))
with engine.connect() as conn:
    result = conn.execute(query)
#result  = engine.execute(query)  for older version
# Out:
# 2023-09-11 22:17:39,942 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 22:17:39,944 INFO sqlalchemy.engine.Engine SELECT `FinalMain`.`Market_Cap`
# FROM `FinalMain`
# 2023-09-11 22:17:39,945 INFO sqlalchemy.engine.Engine [generated in 0.00328s] {}
# 2023-09-11 22:17:39,949 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
Market_caps = []
for row in result:
    money_str = row[0] 
    #money_str = money_str.replace('$', '').replace(',', '')
    money_float = float(money_str)
    Market_caps.append(money_float)

#print(len(Market_caps))

# %%
volume24hs = []
query = select((MainDB.c.volume24h))
with engine.connect() as conn:
    result = conn.execute(query)
#result  = engine.execute(query)  for older version
for row in result:
    volume_str = row[0] 
    #volume_str = volume_str.replace('$', '').replace(',', '')
    volume_str = float(volume_str)
    volume24hs.append(volume_str)
# Out:
# 2023-09-11 22:17:43,270 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 22:17:43,272 INFO sqlalchemy.engine.Engine SELECT `FinalMain`.volume24h
# FROM `FinalMain`
# 2023-09-11 22:17:43,272 INFO sqlalchemy.engine.Engine [generated in 0.00251s] {}
# 2023-09-11 22:17:43,276 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
print(Market_caps)
print(volume24hs)
# Out:
# [507090156466.71, 198709982386.16, 82807252662.66, 33590478887.3, 27845876512.16, 25919090832.39, 9152956074.04, 8878470592.73, 8318053764.65, 6900049920.05, 5458384818.16, 5347822079.04, 5090241628.57, 4897461704.62, 4790996215.75, 4796905977.53, 4243855522.84, 3742379987.32, 3565997081.68, 3459082269.77, 3395969321.15, 3232593123.9, 3153614715.61, 2906332785.19, 2627527906.85, 2563461708.97, 2560000113.73, 2510937180.9, 2282733161.55, 1947264958.07, 1551766082.28, 1434049850.09, 1389503504.21, 1383021589.59, 1294165405.57, 1293223853.59, 1224514289.72, 1208723808.64, 1167316310.31, 1120314403.12, 1052692332.09, 990504480.61, 826232881.8, 816867738.33, 758703967.47, 733226989.17, 723638753.88, 683752252.2, 666749800.85, 661943435.76, 660397460.79, 655307121.86, 645857673.66, 635749025.28, 632186784.21, 608735271.0, 582258459.46, 579354449.45, 578069048.78, 555024528.45, 548179027.6, 533029166.23, 509987125.72, 506141678.92, 504043588.86, 491529841.24, 474111896.22, 472618561.86, 468092957.09, 466662055.23, 461816944.96, 449072864.89, 447781599.08, 442419658.82, 440503374.19, 426293235.96, 407906646.18, 408533685.87, 403210792.05, 402224441.84, 390067399.09, 388737453.15, 388563836.48, 380666189.73, 377292111.77, 373051493.71, 367008700.46, 352099983.62, 345799872.92, 338669192.01, 333203473.32, 331597132.01, 329307564.16, 324120084.27, 319183570.45, 317281942.53, 310553103.67, 310309647.18, 304464153.09, 292018552.81, 285205564.35, 283057029.83, 278385921.23, 273215225.34, 266192636.38, 262758293.88, 259916757.02, 259390286.81, 258458487.51, 254142214.04, 250514511.16, 249594139.73, 243120792.45, 239879871.02, 233371411.7, 230408357.9, 230123909.42, 226756776.59, 222687909.02, 223803293.06, 220872673.57, 219868739.56, 217466370.64, 208826970.64, 204933768.36, 199419911.21, 197729455.63, 196035048.71, 195666273.8, 189768242.79, 190321657.35, 187223432.7, 184678157.7, 184504985.59, 180660096.04, 179857321.91, 177921029.73, 176961202.02, 172051395.02, 170836389.63, 170362619.31, 166961966.86, 166499858.56, 165691080.08, 165422273.7, 163669478.54, 161905219.88, 160633077.22, 160653137.13, 154613096.98, 150348361.81, 149283070.48, 146652257.01, 146000756.62, 143071341.96, 142619354.22, 142196532.56, 139493172.17, 137136497.78, 137400379.15, 136916378.8, 136032462.42, 136209901.34, 134943891.95, 131589746.46, 129646454.31, 127036769.83, 125100518.6, 122466503.22, 122625935.14, 119139451.35, 116876111.22, 114178600.51, 112051075.54, 111284549.85, 109097574.63, 106878901.86, 104229874.78, 103622716.9, 103487619.04, 102255066.05, 100999215.75, 100103068.04, 97438508.25, 96087678.25, 98470191.43, 94519051.53, 87870432.95, 92740883.38, 92571025.39, 92287703.18, 91712920.91, 91355332.57, 90971104.84, 89407039.42, 86940366.42, 86996042.68, 86861435.87, 83853059.08, 82508280.5]
# [12406045117.51, 5396997822.81, 19999153581.65, 423891091.63, 1067427241.27, 2870155394.25, 226745371.9, 202977283.44, 278312420.21, 174447305.16, 94505373.46, 75095538.95, 274560763.21, 29643403.69, 268487447.25, 139371203.42, 76364182.11, 139896933.21, 537932.26, 120285068.43, 89277309.03, 161052214.6, 1079878217.44, 1733339380.82, 87112537.96, 62511771.52, 1728990.68, 87429486.09, 75525218.61, 82946495.9, 16614482.5, 96585090.02, 12277953.46, 67800848.27, 6005789.23, 88396875.79, 12974257.69, 152807293.97, 23309138.0, 47022915.54, 152907326.63, 64448513.14, 68297790.82, 36019315.03, 22762098.11, 10528676.98, 24074045.57, 16559944.78, 49328785.0, 13871033.93, 13463491.1, 15831684.24, 87931284.06, 9643726.7, 35319141.27, 29903353.75, 29980644.43, 16935868.42, 44607866.97, 32694877.37, 25652189.2, 48122107.87, 15049818.82, 21426170.45, 78363548.78, 10826058.77, 4164837.42, 1043454.41, 5883170.07, 24023463.65, 3631508.28, 21821080.48, 39620171.17, 5989536.21, 1545478.38, 17490089.18, 3669231.04, 43281382.96, 3053239.75, 162888635.99, 12908659.91, 16409952.52, 40486695.49, 21749460.65, 5883656.38, 709656.5, 13407651.68, 6300668.69, 275837423.37, 55680344.64, 27745870.48, 2646081.13, 10808744.78, 12467088.15, 20801039.33, 8364316.0, 665745.36, 4926724.29, 16871189.08, 42382421.01, 3635942.35, 13555466.11, 2773749.15, 22890703.54, 9289423.68, 8488734.89, 9010761.33, 11652074.4, 18332639.01, 14697983.67, 76796276.75, 2493014.38, 7950107.13, 9047904.29, 1847724.85, 21824327.41, 7249456.61, 3637894.71, 1816441.53, 25677761.3, 4799292.5, 42448920.27, 5014092.56, 1666662.11, 3536271.7, 7104786.37, 4640807.83, 4523572.86, 21516327.25, 32477076.44, 46599344.67, 7232514.6, 26282427.87, 14461809.97, 3011030.81, 6632930.42, 40368780.24, 18453388.9, 23640637.4, 2591329.18, 10616920.75, 3482186.35, 11715276.53, 9666843.9, 3437076.95, 2467118.41, 7737748.95, 3912022.89, 47733742.84, 9004557.54, 17167568.4, 3898537.54, 2198305.99, 6772888.5, 3856402.04, 4998608.02, 4338715.71, 1301095.9, 5983416.47, 4171444.95, 1792345.42, 6617847.6, 1934672.45, 15341137.26, 16779805.92, 3448326.63, 21525932.09, 6498874.03, 3570494.55, 12043500.87, 13371929.55, 1078056.71, 1195930.34, 2133416.2, 9372284.74, 2050386.87, 855033.54, 435345.29, 4883820.52, 5535973.77, 12542901.39, 4397352.64, 4518427.98, 11389253.2, 2934968.45, 52610535.22, 2537487.22, 4474869.51, 1294868.67, 25218288.55, 5077816.49, 4724978.35, 11055350.26, 2935206.2, 2096473.84, 5954212.5, 1388172.99, 2124704.13, 1634389.39, 3079303.02]

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,7))
sns.scatterplot(x=Market_caps , y=volume24hs)
plt.xlabel("MarketCap")
plt.ylabel("Volume in 1 Day")
plt.title("MarketCap Vs Volume")
# Out:
# Text(0.5, 1.0, 'MarketCap Vs Volume')

# %%
Market_caps2 = pd.Series(Market_caps)
volume24hs2 = pd.Series(volume24hs)
data = pd.DataFrame({'Market_caps': Market_caps2, 
                     'volume24hs': volume24hs2})
data
# Out:
#       Market_caps    volume24hs
# 0    5.070902e+11  1.240605e+10
# 1    1.987100e+11  5.396998e+09
# 2    8.280725e+10  1.999915e+10
# 3    3.359048e+10  4.238911e+08
# 4    2.784588e+10  1.067427e+09
# ..            ...           ...
# 195  8.694037e+07  5.954212e+06
# 196  8.699604e+07  1.388173e+06
# 197  8.686144e+07  2.124704e+06
# 198  8.385306e+07  1.634389e+06
# 199  8.250828e+07  3.079303e+06
#
# [200 rows x 2 columns]

# %%
data = data[ data['Market_caps'] < 1000000000]

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,7))
sns.scatterplot(x = data['Market_caps'], y = data['volume24hs'])
plt.xlabel("MarketCap")
plt.ylabel("Volume in 1 Day")
plt.title("MarketCap Vs Volume")
# Out:
# Text(0.5, 1.0, 'MarketCap Vs Volume')

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سوال ۲
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این تمرین با اطلاعات بیش از ۴۰هزار شهر در قالب یک دیتافریم مواجه می‌شوید و با در یک سال اخیر کدام جفت‌رمزارزها بیشترین روزها با تغییر قیمت هم‌سو را تجربه کرده‌اند و چند روز؟ (منظور از تغییر قیمت همسو افزایش قیمت هر دو رمز ارز یا کاهش قیمت جفت‌شان طی یک روز است) ۳۰ جفت رمزارز برتر را نخست به ترتیب تعداد روز همسو، سپس نام رمز ارز اول و در نهایت نام رمز ارز دوم نمایش دهید؛ همچنین توجه داشته باشید همواره نام رمزارز اول از نظر حروف الفبا مقدم بر نام رمز ارز دوم باشد.
# </font>
# </p>

# %%
conn = engine.connect()
metadata = db.MetaData()

# %%
sql = "select * from FinalMain"
testDf = pd.DataFrame(conn.execute(db.text(sql)))
#testDf.head()
# Out:
# 2023-09-11 13:12:56,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 13:12:56,627 INFO sqlalchemy.engine.Engine select * from FinalMain
# 2023-09-11 13:12:56,628 INFO sqlalchemy.engine.Engine [generated in 0.00259s] {}

# %%
sql = "select distinct CombinedCSV.name from CombinedCSV"
names = pd.DataFrame(conn.execute(db.text(sql)))
#names.head()
# Out:
# 2023-09-11 13:12:57,816 INFO sqlalchemy.engine.Engine select distinct CombinedCSV.name from CombinedCSV
# 2023-09-11 13:12:57,817 INFO sqlalchemy.engine.Engine [generated in 0.00080s] {}

# %%
coins = []
for name in names['name']:
    sql = "select * from CombinedCSV where CombinedCSV.name = \"" + name + "\"";
    coin = pd.DataFrame(conn.execute(db.text(sql)))
    coins.append(coin)
# Out:
# 2023-09-11 13:12:59,086 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "0x Protocol"
# 2023-09-11 13:12:59,087 INFO sqlalchemy.engine.Engine [generated in 0.00099s] {}
# 2023-09-11 13:12:59,140 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "1inch Network"
# 2023-09-11 13:12:59,141 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {}
# 2023-09-11 13:12:59,181 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Aave"
# 2023-09-11 13:12:59,182 INFO sqlalchemy.engine.Engine [generated in 0.00070s] {}
# 2023-09-11 13:12:59,219 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "aelf"
# 2023-09-11 13:12:59,219 INFO sqlalchemy.engine.Engine [generated in 0.00044s] {}
# 2023-09-11 13:12:59,253 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Akash Network"
# 2023-09-11 13:12:59,254 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:12:59,287 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Alchemy Pay"
# 2023-09-11 13:12:59,288 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {}
# 2023-09-11 13:12:59,321 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Algorand"
# 2023-09-11 13:12:59,322 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:12:59,355 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Amp"
# 2023-09-11 13:12:59,356 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {}
# 2023-09-11 13:12:59,389 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ankr"
# 2023-09-11 13:12:59,389 INFO sqlalchemy.engine.Engine [generated in 0.00061s] {}
# 2023-09-11 13:12:59,425 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "ApeCoin"
# 2023-09-11 13:12:59,426 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {}
# 2023-09-11 13:12:59,461 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "APENFT"
# 2023-09-11 13:12:59,461 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2023-09-11 13:12:59,496 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Aptos"
# 2023-09-11 13:12:59,496 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:12:59,532 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Aragon"
# 2023-09-11 13:12:59,533 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:12:59,569 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Arbitrum"
# 2023-09-11 13:12:59,570 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:12:59,604 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Arweave"
# 2023-09-11 13:12:59,604 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:12:59,641 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Astar"
# 2023-09-11 13:12:59,641 INFO sqlalchemy.engine.Engine [generated in 0.00062s] {}
# 2023-09-11 13:12:59,677 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Audius"
# 2023-09-11 13:12:59,678 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:12:59,714 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Avalanche"
# 2023-09-11 13:12:59,714 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:12:59,750 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Axelar"
# 2023-09-11 13:12:59,750 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:12:59,786 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Axie Infinity"
# 2023-09-11 13:12:59,786 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {}
# 2023-09-11 13:12:59,823 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Balancer"
# 2023-09-11 13:12:59,823 INFO sqlalchemy.engine.Engine [generated in 0.00049s] {}
# 2023-09-11 13:12:59,858 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Band Protocol"
# 2023-09-11 13:12:59,858 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# 2023-09-11 13:12:59,893 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Basic Attention Token"
# 2023-09-11 13:12:59,894 INFO sqlalchemy.engine.Engine [generated in 0.00051s] {}
# 2023-09-11 13:12:59,927 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Biconomy"
# 2023-09-11 13:12:59,928 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# 2023-09-11 13:12:59,961 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Binance USD"
# 2023-09-11 13:12:59,961 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:12:59,994 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Bitcoin Cash"
# 2023-09-11 13:12:59,995 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,028 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Bitcoin Gold"
# 2023-09-11 13:13:00,028 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:00,062 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Bitcoin SV"
# 2023-09-11 13:13:00,062 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:00,094 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Bitcoin"
# 2023-09-11 13:13:00,095 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,128 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "BitTorrent(New)"
# 2023-09-11 13:13:00,128 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,161 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Blur"
# 2023-09-11 13:13:00,161 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,194 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "BNB"
# 2023-09-11 13:13:00,194 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,226 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Bone ShibaSwap"
# 2023-09-11 13:13:00,227 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:00,259 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "BORA"
# 2023-09-11 13:13:00,260 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:00,292 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Cardano"
# 2023-09-11 13:13:00,293 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,326 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Cartesi"
# 2023-09-11 13:13:00,327 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,360 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Casper"
# 2023-09-11 13:13:00,360 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,394 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Celer Network"
# 2023-09-11 13:13:00,394 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,426 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Celo"
# 2023-09-11 13:13:00,427 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# 2023-09-11 13:13:00,460 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Chainlink"
# 2023-09-11 13:13:00,461 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:00,493 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Chia"
# 2023-09-11 13:13:00,494 INFO sqlalchemy.engine.Engine [generated in 0.00131s] {}
# 2023-09-11 13:13:00,527 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Chiliz"
# 2023-09-11 13:13:00,527 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,560 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Compound"
# 2023-09-11 13:13:00,560 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:00,595 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Conflux"
# 2023-09-11 13:13:00,596 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:00,628 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Convex Finance"
# 2023-09-11 13:13:00,629 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:00,661 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Core"
# 2023-09-11 13:13:00,661 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:00,693 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Cosmos"
# 2023-09-11 13:13:00,693 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,726 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Cronos"
# 2023-09-11 13:13:00,726 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,759 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Curve DAO Token"
# 2023-09-11 13:13:00,760 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:00,793 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Dai"
# 2023-09-11 13:13:00,793 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,826 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "DAO Maker"
# 2023-09-11 13:13:00,826 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:00,861 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Dash"
# 2023-09-11 13:13:00,862 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:00,897 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Decentraland"
# 2023-09-11 13:13:00,897 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:00,932 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Decred"
# 2023-09-11 13:13:00,932 INFO sqlalchemy.engine.Engine [generated in 0.00056s] {}
# 2023-09-11 13:13:00,966 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "DigiByte"
# 2023-09-11 13:13:00,966 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:01,000 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Dogecoin"
# 2023-09-11 13:13:01,000 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2023-09-11 13:13:01,034 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "dYdX"
# 2023-09-11 13:13:01,034 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:01,067 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "eCash"
# 2023-09-11 13:13:01,067 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,102 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Enjin Coin"
# 2023-09-11 13:13:01,103 INFO sqlalchemy.engine.Engine [generated in 0.00093s] {}
# 2023-09-11 13:13:01,136 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "EOS"
# 2023-09-11 13:13:01,137 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:01,169 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ethereum Classic"
# 2023-09-11 13:13:01,170 INFO sqlalchemy.engine.Engine [generated in 0.00043s] {}
# 2023-09-11 13:13:01,204 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ethereum Name Service"
# 2023-09-11 13:13:01,205 INFO sqlalchemy.engine.Engine [generated in 0.00047s] {}
# 2023-09-11 13:13:01,239 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ethereum"
# 2023-09-11 13:13:01,239 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:01,273 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "EthereumPoW"
# 2023-09-11 13:13:01,273 INFO sqlalchemy.engine.Engine [generated in 0.00047s] {}
# 2023-09-11 13:13:01,308 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Everscale"
# 2023-09-11 13:13:01,308 INFO sqlalchemy.engine.Engine [generated in 0.00041s] {}
# 2023-09-11 13:13:01,341 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Fantom"
# 2023-09-11 13:13:01,341 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,377 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Fetch.ai"
# 2023-09-11 13:13:01,377 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:01,412 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Filecoin"
# 2023-09-11 13:13:01,413 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:01,446 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Flare"
# 2023-09-11 13:13:01,446 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:01,480 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "FLOKI"
# 2023-09-11 13:13:01,480 INFO sqlalchemy.engine.Engine [generated in 0.00088s] {}
# 2023-09-11 13:13:01,513 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Flow"
# 2023-09-11 13:13:01,514 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,547 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Flux"
# 2023-09-11 13:13:01,548 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:01,581 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Frax Share"
# 2023-09-11 13:13:01,581 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:01,614 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Gala"
# 2023-09-11 13:13:01,614 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:01,647 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Galxe"
# 2023-09-11 13:13:01,648 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:01,680 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "GateToken"
# 2023-09-11 13:13:01,680 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,713 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Gemini Dollar"
# 2023-09-11 13:13:01,713 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:01,745 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "GMX"
# 2023-09-11 13:13:01,746 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:01,780 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Gnosis"
# 2023-09-11 13:13:01,780 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:01,813 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Golem"
# 2023-09-11 13:13:01,813 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,846 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Harmony"
# 2023-09-11 13:13:01,846 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,880 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Hedera"
# 2023-09-11 13:13:01,880 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,915 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Helium"
# 2023-09-11 13:13:01,916 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2023-09-11 13:13:01,948 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Hive"
# 2023-09-11 13:13:01,949 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:01,984 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Holo"
# 2023-09-11 13:13:01,984 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2023-09-11 13:13:02,016 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Horizen"
# 2023-09-11 13:13:02,017 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:02,050 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Huobi Token"
# 2023-09-11 13:13:02,050 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:02,084 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "ICON"
# 2023-09-11 13:13:02,084 INFO sqlalchemy.engine.Engine [generated in 0.00047s] {}
# 2023-09-11 13:13:02,120 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Illuvium"
# 2023-09-11 13:13:02,120 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:02,154 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Immutable"
# 2023-09-11 13:13:02,155 INFO sqlalchemy.engine.Engine [generated in 0.00096s] {}
# 2023-09-11 13:13:02,189 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Injective"
# 2023-09-11 13:13:02,189 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:02,224 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Internet Computer"
# 2023-09-11 13:13:02,224 INFO sqlalchemy.engine.Engine [generated in 0.00050s] {}
# 2023-09-11 13:13:02,257 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "IOST"
# 2023-09-11 13:13:02,257 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:02,289 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "IOTA"
# 2023-09-11 13:13:02,290 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:02,323 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "IoTeX"
# 2023-09-11 13:13:02,323 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:02,356 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "JasmyCoin"
# 2023-09-11 13:13:02,356 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:02,388 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "JUST"
# 2023-09-11 13:13:02,389 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:02,422 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Kadena"
# 2023-09-11 13:13:02,422 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:02,456 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Kava"
# 2023-09-11 13:13:02,457 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:02,504 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Klaytn"
# 2023-09-11 13:13:02,511 INFO sqlalchemy.engine.Engine [generated in 0.00633s] {}
# 2023-09-11 13:13:02,569 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "KuCoin Token"
# 2023-09-11 13:13:02,569 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:02,602 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Kusama"
# 2023-09-11 13:13:02,602 INFO sqlalchemy.engine.Engine [generated in 0.00041s] {}
# 2023-09-11 13:13:02,635 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Kyber Network Crystal v2"
# 2023-09-11 13:13:02,636 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# 2023-09-11 13:13:02,668 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Lido DAO"
# 2023-09-11 13:13:02,668 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:02,702 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Lisk"
# 2023-09-11 13:13:02,702 INFO sqlalchemy.engine.Engine [generated in 0.00041s] {}
# 2023-09-11 13:13:02,735 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Litecoin"
# 2023-09-11 13:13:02,735 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:02,790 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Livepeer"
# 2023-09-11 13:13:02,791 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:02,824 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Loopring"
# 2023-09-11 13:13:02,824 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:02,857 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "MAGIC"
# 2023-09-11 13:13:02,857 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:02,890 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Maker"
# 2023-09-11 13:13:02,890 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:02,923 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Mantle"
# 2023-09-11 13:13:02,923 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:02,955 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Mask Network"
# 2023-09-11 13:13:02,955 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:02,988 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Merit Circle"
# 2023-09-11 13:13:02,988 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:03,020 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Mina"
# 2023-09-11 13:13:03,021 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,054 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "MobileCoin"
# 2023-09-11 13:13:03,054 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,087 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Monero"
# 2023-09-11 13:13:03,087 INFO sqlalchemy.engine.Engine [generated in 0.00032s] {}
# 2023-09-11 13:13:03,119 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Moonbeam"
# 2023-09-11 13:13:03,119 INFO sqlalchemy.engine.Engine [generated in 0.00043s] {}
# 2023-09-11 13:13:03,153 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "MultiversX"
# 2023-09-11 13:13:03,153 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# 2023-09-11 13:13:03,187 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "MX TOKEN"
# 2023-09-11 13:13:03,188 INFO sqlalchemy.engine.Engine [generated in 0.00086s] {}
# 2023-09-11 13:13:03,222 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Nano"
# 2023-09-11 13:13:03,223 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:03,256 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "NEAR Protocol"
# 2023-09-11 13:13:03,256 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:03,288 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "NEM"
# 2023-09-11 13:13:03,288 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:03,323 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Neo"
# 2023-09-11 13:13:03,323 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2023-09-11 13:13:03,356 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Nervos Network"
# 2023-09-11 13:13:03,356 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,390 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Nexo"
# 2023-09-11 13:13:03,390 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:03,424 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Oasis Network"
# 2023-09-11 13:13:03,424 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:03,456 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ocean Protocol"
# 2023-09-11 13:13:03,457 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:03,489 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "OKB"
# 2023-09-11 13:13:03,489 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,521 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ontology"
# 2023-09-11 13:13:03,522 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,554 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Optimism"
# 2023-09-11 13:13:03,555 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:03,590 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Osmosis"
# 2023-09-11 13:13:03,590 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {}
# 2023-09-11 13:13:03,625 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "PancakeSwap"
# 2023-09-11 13:13:03,625 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# 2023-09-11 13:13:03,657 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Pax Dollar"
# 2023-09-11 13:13:03,658 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {}
# 2023-09-11 13:13:03,691 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "PAX Gold"
# 2023-09-11 13:13:03,691 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:03,723 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Pepe"
# 2023-09-11 13:13:03,724 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:03,755 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "PlayDapp"
# 2023-09-11 13:13:03,756 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,789 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Polkadot"
# 2023-09-11 13:13:03,789 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:03,823 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Polygon"
# 2023-09-11 13:13:03,823 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:03,856 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Pundi X (New)"
# 2023-09-11 13:13:03,856 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:03,888 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Qtum"
# 2023-09-11 13:13:03,889 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:03,922 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Quant"
# 2023-09-11 13:13:03,922 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:03,954 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ravencoin"
# 2023-09-11 13:13:03,955 INFO sqlalchemy.engine.Engine [generated in 0.00055s] {}
# 2023-09-11 13:13:03,990 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Render"
# 2023-09-11 13:13:03,990 INFO sqlalchemy.engine.Engine [generated in 0.00042s] {}
# 2023-09-11 13:13:04,023 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Reserve Rights"
# 2023-09-11 13:13:04,023 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:04,056 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Ribbon Finance"
# 2023-09-11 13:13:04,056 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:04,088 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Rocket Pool"
# 2023-09-11 13:13:04,089 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:04,121 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "SafePal"
# 2023-09-11 13:13:04,121 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:04,154 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Sei"
# 2023-09-11 13:13:04,155 INFO sqlalchemy.engine.Engine [generated in 0.00060s] {}
# 2023-09-11 13:13:04,189 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Shiba Inu"
# 2023-09-11 13:13:04,189 INFO sqlalchemy.engine.Engine [generated in 0.00048s] {}
# 2023-09-11 13:13:04,222 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Siacoin"
# 2023-09-11 13:13:04,222 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:04,256 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "SingularityNET"
# 2023-09-11 13:13:04,256 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# 2023-09-11 13:13:04,288 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "SKALE"
# 2023-09-11 13:13:04,288 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:04,321 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Solana"
# 2023-09-11 13:13:04,321 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:04,353 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Solar"
# 2023-09-11 13:13:04,353 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:04,386 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "ssv.network"
# 2023-09-11 13:13:04,387 INFO sqlalchemy.engine.Engine [generated in 0.00032s] {}
# 2023-09-11 13:13:04,419 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Stacks"
# 2023-09-11 13:13:04,419 INFO sqlalchemy.engine.Engine [generated in 0.00039s] {}
# 2023-09-11 13:13:04,452 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Stargate Finance"
# 2023-09-11 13:13:04,452 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {}
# 2023-09-11 13:13:04,485 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Status"
# 2023-09-11 13:13:04,485 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:04,520 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Stellar"
# 2023-09-11 13:13:04,520 INFO sqlalchemy.engine.Engine [generated in 0.00050s] {}
# 2023-09-11 13:13:04,553 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "STEPN"
# 2023-09-11 13:13:04,553 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:04,586 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Storj"
# 2023-09-11 13:13:04,587 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:04,619 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "STP"
# 2023-09-11 13:13:04,620 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:04,654 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Sui"
# 2023-09-11 13:13:04,655 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:04,688 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "SushiSwap"
# 2023-09-11 13:13:04,688 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {}
# 2023-09-11 13:13:04,721 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Synthetix"
# 2023-09-11 13:13:04,722 INFO sqlalchemy.engine.Engine [generated in 0.00031s] {}
# 2023-09-11 13:13:04,754 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Terra Classic"
# 2023-09-11 13:13:04,755 INFO sqlalchemy.engine.Engine [generated in 0.00043s] {}
# 2023-09-11 13:13:04,803 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Terra"
# 2023-09-11 13:13:04,804 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:04,837 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "TerraClassicUSD"
# 2023-09-11 13:13:04,837 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:04,869 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Tether Gold"
# 2023-09-11 13:13:04,870 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:04,902 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Tether USDt"
# 2023-09-11 13:13:04,903 INFO sqlalchemy.engine.Engine [generated in 0.00045s] {}
# 2023-09-11 13:13:04,935 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Tezos"
# 2023-09-11 13:13:04,935 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:04,967 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "The Graph"
# 2023-09-11 13:13:04,968 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,000 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "The Sandbox"
# 2023-09-11 13:13:05,001 INFO sqlalchemy.engine.Engine [generated in 0.00095s] {}
# 2023-09-11 13:13:05,034 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Theta Fuel"
# 2023-09-11 13:13:05,034 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,069 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Theta Network"
# 2023-09-11 13:13:05,070 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# 2023-09-11 13:13:05,103 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "THORChain"
# 2023-09-11 13:13:05,104 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,137 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Threshold"
# 2023-09-11 13:13:05,137 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:05,170 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "TomoChain"
# 2023-09-11 13:13:05,170 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,204 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Toncoin"
# 2023-09-11 13:13:05,205 INFO sqlalchemy.engine.Engine [generated in 0.00047s] {}
# 2023-09-11 13:13:05,238 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "TRON"
# 2023-09-11 13:13:05,239 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:05,272 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "TrueUSD"
# 2023-09-11 13:13:05,272 INFO sqlalchemy.engine.Engine [generated in 0.00038s] {}
# 2023-09-11 13:13:05,307 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Trust Wallet Token"
# 2023-09-11 13:13:05,307 INFO sqlalchemy.engine.Engine [generated in 0.00030s] {}
# 2023-09-11 13:13:05,341 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "UMA"
# 2023-09-11 13:13:05,341 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:05,374 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "UniBot"
# 2023-09-11 13:13:05,375 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:05,406 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Uniswap"
# 2023-09-11 13:13:05,406 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}
# 2023-09-11 13:13:05,441 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "UNUS SED LEO"
# 2023-09-11 13:13:05,442 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:05,476 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "USD Coin"
# 2023-09-11 13:13:05,476 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:05,509 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "USDD"
# 2023-09-11 13:13:05,509 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,543 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "VeChain"
# 2023-09-11 13:13:05,543 INFO sqlalchemy.engine.Engine [generated in 0.00032s] {}
# 2023-09-11 13:13:05,576 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Vulcan Forged PYR"
# 2023-09-11 13:13:05,577 INFO sqlalchemy.engine.Engine [generated in 0.00040s] {}
# 2023-09-11 13:13:05,609 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Waves"
# 2023-09-11 13:13:05,609 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:05,642 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "WAX"
# 2023-09-11 13:13:05,643 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,676 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "WOO Network"
# 2023-09-11 13:13:05,677 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:05,711 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Worldcoin"
# 2023-09-11 13:13:05,711 INFO sqlalchemy.engine.Engine [generated in 0.00037s] {}
# 2023-09-11 13:13:05,743 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Wrapped Bitcoin"
# 2023-09-11 13:13:05,743 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:05,777 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "XDC Network"
# 2023-09-11 13:13:05,777 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {}
# 2023-09-11 13:13:05,811 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "XRP"
# 2023-09-11 13:13:05,812 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,847 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "yearn.finance"
# 2023-09-11 13:13:05,847 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}
# 2023-09-11 13:13:05,882 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Zcash"
# 2023-09-11 13:13:05,882 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {}
# 2023-09-11 13:13:05,958 INFO sqlalchemy.engine.Engine select * from CombinedCSV where CombinedCSV.name = "Zilliqa"
# 2023-09-11 13:13:05,959 INFO sqlalchemy.engine.Engine [generated in 0.00036s] {}

# %%
'''directory = 'top200'
coins = []

for filename in os.scandir(directory):
    if(filename.is_file() and Path(filename).suffix in ['.csv']):
        df = pd.read_csv(filename, sep=';', parse_dates=[1,2,3,4,11])
        coins.append(df)'''
# Out:
# "directory = 'top200'\ncoins = []\n\nfor filename in os.scandir(directory):\n    if(filename.is_file() and Path(filename).suffix in ['.csv']):\n        df = pd.read_csv(filename, sep=';', parse_dates=[1,2,3,4,11])\n        coins.append(df)"

# %%
coins[0].head()
# Out:
#    index         Name                  timeOpen                 timeClose  \
# 0      0  0x Protocol  2023-09-01T00:00:00.000Z  2023-09-01T23:59:59.999Z
# 1      1  0x Protocol  2023-08-31T00:00:00.000Z  2023-08-31T23:59:59.999Z
# 2      2  0x Protocol  2023-08-30T00:00:00.000Z  2023-08-30T23:59:59.999Z
# 3      3  0x Protocol  2023-08-29T00:00:00.000Z  2023-08-29T23:59:59.999Z
# 4      4  0x Protocol  2023-08-28T00:00:00.000Z  2023-08-28T23:59:59.999Z
#
#                    timeHigh                   timeLow      open      high  \
# 0  2023-09-01T00:50:00.000Z  2023-09-01T17:43:00.000Z  0.165031  0.166129
# 1  2023-08-31T11:59:00.000Z  2023-08-31T21:10:00.000Z  0.173477  0.173825
# 2  2023-08-30T00:04:00.000Z  2023-08-30T18:35:00.000Z  0.179006  0.179208
# 3  2023-08-29T17:37:00.000Z  2023-08-29T10:40:00.000Z  0.171287  0.179883
# 4  2023-08-28T03:01:00.000Z  2023-08-28T08:41:00.000Z  0.171732  0.173390
#
#         low     close      volume     marketCap                 timestamp
# 0  0.160861  0.162285  5871295.09  1.375358e+08  2023-09-01T23:59:59.999Z
# 1  0.163603  0.165032  8818782.31  1.398643e+08  2023-08-31T23:59:59.999Z
# 2  0.172838  0.173472  5742333.46  1.470167e+08  2023-08-30T23:59:59.999Z
# 3  0.166246  0.179005  8196429.59  1.517058e+08  2023-08-29T23:59:59.999Z
# 4  0.167069  0.171301  8435254.17  1.451768e+08  2023-08-28T23:59:59.999Z

# %%
num_coins = len(coins)
top_related_coins = np.zeros((31,3))
for i in range(num_coins):
    dif1 = coins[i]['close'] - coins[i]['open']
    
    for j in range(i + 1, num_coins):
        dif2 = coins[j]['close'] - coins[j]['open']
        num_cons_days = 0
        max_num_days = 0
        #print(coins[i]['Name'][0], coins[j]['Name'][0])
        #print(len(dif1), len(dif2))
        for k in range(min(len(dif1), len(dif2))):
            if(dif1[k] * dif2[k] >= 0):
                num_cons_days += 1
            else:
                num_cons_days = 0
            max_num_days = max(max_num_days, num_cons_days)
        
        #print(np.array([max_num_days, i, j]))        
        top_related_coins[0] = np.array([max_num_days, i, j])
        #print(top_related_coins)
        top_related_coins = top_related_coins[top_related_coins[:,0].argsort(kind='mergesort')]
        #print(top_related_coins)

# %%
#print(top_related_coins)
for i in range(30, 0, -1):
    coin1 = coins[int(top_related_coins[i][1])]['Name'][0]
    coin2 = coins[int(top_related_coins[i][2])]['Name'][0]
    cnt = top_related_coins[i][0]
    print('Coin 1:', coin1, '\nCoin 2:', coin2, '\nNumber of Days:', cnt, '\n')
# Out:
# Coin 1: Bitcoin
# Coin 2: Wrapped Bitcoin
# Number of Days: 90.0
#
# Coin 1: Fetch.ai
# Coin 2: The Graph
# Number of Days: 57.0
#
# Coin 1: Decentraland
# Coin 2: VeChain
# Number of Days: 55.0
#
# Coin 1: Compound
# Coin 2: The Sandbox
# Number of Days: 52.0
#
# Coin 1: Compound
# Coin 2: Tezos
# Number of Days: 49.0
#
# Coin 1: Ethereum
# Coin 2: Gnosis
# Number of Days: 46.0
#
# Coin 1: Ankr
# Coin 2: ICON
# Number of Days: 45.0
#
# Coin 1: Axie Infinity
# Coin 2: IoTeX
# Number of Days: 45.0
#
# Coin 1: 0x Protocol
# Coin 2: Ravencoin
# Number of Days: 44.0
#
# Coin 1: Basic Attention Token
# Coin 2: Livepeer
# Number of Days: 43.0
#
# Coin 1: Ethereum
# Coin 2: SafePal
# Number of Days: 43.0
#
# Coin 1: Frax Share
# Coin 2: Polygon
# Number of Days: 43.0
#
# Coin 1: Aave
# Coin 2: Flow
# Number of Days: 42.0
#
# Coin 1: Ankr
# Coin 2: DigiByte
# Number of Days: 42.0
#
# Coin 1: Avalanche
# Coin 2: EthereumPoW
# Number of Days: 42.0
#
# Coin 1: Axie Infinity
# Coin 2: Compound
# Number of Days: 42.0
#
# Coin 1: Axie Infinity
# Coin 2: The Sandbox
# Number of Days: 42.0
#
# Coin 1: Band Protocol
# Coin 2: Solar
# Number of Days: 42.0
#
# Coin 1: Harmony
# Coin 2: Immutable
# Number of Days: 42.0
#
# Coin 1: Livepeer
# Coin 2: The Graph
# Number of Days: 42.0
#
# Coin 1: Ravencoin
# Coin 2: Theta Network
# Number of Days: 42.0
#
# Coin 1: 0x Protocol
# Coin 2: Theta Network
# Number of Days: 41.0
#
# Coin 1: Aave
# Coin 2: Basic Attention Token
# Number of Days: 41.0
#
# Coin 1: Aave
# Coin 2: Livepeer
# Number of Days: 41.0
#
# Coin 1: Algorand
# Coin 2: Filecoin
# Number of Days: 41.0
#
# Coin 1: Axie Infinity
# Coin 2: VeChain
# Number of Days: 41.0
#
# Coin 1: DigiByte
# Coin 2: Filecoin
# Number of Days: 41.0
#
# Coin 1: Enjin Coin
# Coin 2: Fantom
# Number of Days: 41.0
#
# Coin 1: Harmony
# Coin 2: Ocean Protocol
# Number of Days: 41.0
#
# Coin 1: Harmony
# Coin 2: SushiSwap
# Number of Days: 41.0

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سوال ۳
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# توزیع حجم معاملات روزانه رمزارزهای قابل استخراج  (Mineable) را رسم کنید.
# </font>
# </p>

# %%
meta = MetaData()
Tags = Table(
    'Tags',
    meta,
    Column('rank', Integer, primary_key=True),
    Column('name', String(255)),
    Column('tags', String(255))
)

CombinedCSV = Table(
    'CombinedCSV',
    meta,
    Column('name', String(255), primary_key=True),
    Column('time_open', String(255)),
    Column('time_close', String(255)),
    Column('time_high', String(255)),
    Column('time_low', String(255)),
    Column('open', Float),
    Column('high', Float),
    Column('low', Float),
    Column('close', Float),
    Column('volume', Float),
    Column('market_cap', Float),
    Column('timestamp', String(255))
)


Session = sessionmaker(bind=engine)
session = Session()

# %%
mineable_tags = ['mineable']

mineable_cryptos = (
    session.query(Tags.c.name)
    .filter(Tags.c.tags.ilike('%mineable%'))
    .all()
)
mineable_crypto_names = [crypto.name for crypto in mineable_cryptos]
# Out:
# 2023-09-11 21:58:25,558 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-09-11 21:58:25,559 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 21:58:25,561 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-09-11 21:58:25,561 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 21:58:25,563 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-09-11 21:58:25,563 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 21:58:25,564 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 21:58:25,565 INFO sqlalchemy.engine.Engine SELECT `Tags`.name AS `Tags_name`
# FROM `Tags`
# WHERE lower(`Tags`.tags) LIKE lower(%(tags_1)s)
# 2023-09-11 21:58:25,566 INFO sqlalchemy.engine.Engine [generated in 0.00035s] {'tags_1': '%mineable%'}

# %%
mineable_crypto_volume = (
    session.query(CombinedCSV.c.volume)
    .filter(CombinedCSV.c.name.in_(mineable_crypto_names))
    .all()
)

volume_data = [data.volume for data in mineable_crypto_volume]
#print(len(volume_data))
# Out:
# 2023-09-11 21:58:27,778 INFO sqlalchemy.engine.Engine SELECT `CombinedCSV`.volume AS `CombinedCSV_volume`
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name IN (%(name_1_1)s, %(name_1_2)s, %(name_1_3)s, %(name_1_4)s, %(name_1_5)s, %(name_1_6)s, %(name_1_7)s, %(name_1_8)s, %(name_1_9)s, %(name_1_10)s, %(name_1_11)s, %(name_1_12)s, %(name_1_13)s, %(name_1_14)s, %(name_1_15)s, %(name_1_16)s, %(name_1_17)s, %(name_1_18)s, %(name_1_19)s, %(name_1_20)s, %(name_1_21)s, %(name_1_22)s)
# 2023-09-11 21:58:27,780 INFO sqlalchemy.engine.Engine [generated in 0.00222s] {'name_1_1': 'Bitcoin', 'name_1_2': 'Dogecoin', 'name_1_3': 'Litecoin', 'name_1_4': 'Bitcoin Cash', 'name_1_5': 'Monero', 'name_1_6': 'Ethereum Classic', 'name_1_7': 'Filecoin', 'name_1_8': 'Stacks', 'name_1_9': 'Bitcoin SV', 'name_1_10': 'Zcash', 'name_1_11': 'Conflux', 'name_1_12': 'Dash', 'name_1_13': 'Zilliqa', 'name_1_14': 'Qtum', 'name_1_15': 'SingularityNET', 'name_1_16': 'Ankr', 'name_1_17': 'Osmosis', 'name_1_18': 'Worldcoin', 'name_1_19': 'DAO Maker', 'name_1_20': 'MobileCoin', 'name_1_21': 'Reserve Rights', 'name_1_22': 'Everscale'}

# %%
plt.hist(volume_data, bins=250, alpha=0.5, color='blue', edgecolor='black')
plt.xlabel('Daily Trading Volume')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Trading Volume for Mineable Cryptocurrencies')
plt.grid(True)
plt.show()

# %%
volume_data2 = pd.Series(volume_data)
volume_data2 = volume_data2[volume_data2 < 100000000]
volume_data2
# Out:
# 0        6744198.80
# 1       11037057.78
# 2        7596591.60
# 3       12721846.75
# 4        7677163.36
#            ...
# 7671    56575703.85
# 7672    59656282.98
# 7681    72999569.79
# 7682    52849221.42
# 7683    46434392.47
# Length: 5254, dtype: float64

# %%
plt.hist(volume_data2, bins=250, alpha=0.5, color='blue', edgecolor='black')
plt.xlabel('Daily Trading Volume')
plt.ylabel('Frequency')
plt.title('Distribution of Daily Trading Volume for Mineable Cryptocurrencies')
plt.grid(True)
plt.show()

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سوال ۴
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ماتریس هم‌بستگی را برای تغییرات قیمت ۱۶ رمزارز برتر از نظر ارزش بازار رسم نمایید.
# </font>
# </p>

# %%
#sum_coins = pd.read_csv('Top200Main.csv')
sum_coins = testDf
#sum_coins.head()

# %%
top16_coins_names = sum_coins['Name'][:16]
#print(top16_coins_names)
top16_coins_dif = pd.DataFrame()

# %%
for coin in coins:
    CName = coin['Name'][0]
    if(CName in list(top16_coins_names)):
        dif = coin['close'] - coin['open']
        top16_coins_dif[CName] = dif

# %%
corr = top16_coins_dif.corr()
fix, ax = plt.subplots(figsize=(15,10))
sns.heatmap(corr, ax=ax, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سوال ۵
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# روزهایی که بیش از ۳۵ درصد رمزارزهای مورد مطالعه افزایش قیمت (تفاوت close و open روز) را تجربه می‌کنند روزهای سبز و دیگر روزها را روزهای قرمز بازار می‌نامیم. ۱۰ رمزارز که بیش‌ترین تعداد افزایش قیمت را در روز‌های قرمز در بهار ۲۰۲۳ (برج‌های ۳، ۴ و ۵ میلادی) تجربه کرده‌اند کدام رمز‌ارز‌ها هستند؟ حجم بازار‌ این ۱۰ رمز‌ارز‌ را به صورت نمودار میله‌ای نمایش دهید.
# </font>
# </p>

# %%
meta = MetaData()

CombinedCSV = Table(
    'CombinedCSV',
    meta,
    Column('name', String(255), primary_key=True),
    Column('time_open', String(255)),
    Column('time_close', String(255)),
    Column('time_high', String(255)),
    Column('time_low', String(255)),
    Column('open', Float),
    Column('high', Float),
    Column('low', Float),
    Column('close', Float),
    Column('volume', Float),
    Column('market_cap', Float),
    Column('timestamp', String(255))
)

Session = sessionmaker(bind=engine)
session = Session()

# %%
start_date = '2023-03-01'
end_date = '2023-05-31'

spring_data = (
    session.query(CombinedCSV.c.name, CombinedCSV.c.timestamp, CombinedCSV.c.close, CombinedCSV.c.open, CombinedCSV.c.volume)
    .filter(CombinedCSV.c.timestamp >= start_date, CombinedCSV.c.timestamp <= end_date)
    .all()
)
df = pd.DataFrame(spring_data, columns=['name', 'timestamp', 'close', 'open', 'volume'])

df['percentage_change'] = ((df['close'] - df['open']) / df['open']) * 100

red_market_days = df.groupby('timestamp')['percentage_change'].apply(lambda x: (x > 0).mean() < 0.35)

red_days_count = df[df['timestamp'].isin(red_market_days[red_market_days].index)].groupby('name').size()

top_10_red_days = red_days_count.nlargest(10).index

top_10_market_volumes = df[df['name'].isin(top_10_red_days)].groupby('name')['volume'].sum()
# Out:
# 2023-09-11 20:03:40,940 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 20:03:40,950 INFO sqlalchemy.engine.Engine SELECT `CombinedCSV`.name AS `CombinedCSV_name`, `CombinedCSV`.timestamp AS `CombinedCSV_timestamp`, `CombinedCSV`.close AS `CombinedCSV_close`, `CombinedCSV`.open AS `CombinedCSV_open`, `CombinedCSV`.volume AS `CombinedCSV_volume`
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.timestamp >= %(timestamp_1)s AND `CombinedCSV`.timestamp <= %(timestamp_2)s
# 2023-09-11 20:03:40,950 INFO sqlalchemy.engine.Engine [generated in 0.00149s] {'timestamp_1': '2023-03-01', 'timestamp_2': '2023-05-31'}

# %%
plt.figure(figsize=(12, 6))
top_10_market_volumes.plot(kind='bar', color='green', alpha=0.7)
plt.title('Market Volume of Top 10 Cryptocurrencies During Red Market Days (Spring 2023)')
plt.xlabel('Cryptocurrency')
plt.ylabel('Market Volume')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تخمین
# </font>
# </h2>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# به‌صورت تصادفی ۴۰ رمز ارز را از میان داده‌های استخراج شده انتخاب نمایید و میانگین حجم معاملاتی روزانه هر یک را به‌دست آورید. طبق این نمونه برداری بازه‌ی اطمینان ۹۸ درصد را برای حجم معاملاتی محاسبه نمایید.
# </font>
# </p>

# %%
meta = MetaData()

csv4 = Table(
    'CombinedCSV',
    meta,
    Column('name', String(255), primary_key=True),
    Column('time_open', String(255)),
    Column('time_close', String(255)),
    Column('time_high', String(255)),
    Column('time_low', String(255)),
    Column('open', Float),
    Column('high', Float),
    Column('low', Float),
    Column('close', Float),
    Column('volume', Float),
    Column('market_cap', Float),
    Column('timestamp', String(255))
)

Session = sessionmaker(bind=engine)
session = Session()

# %%
query = session.query(CombinedCSV.c.name, CombinedCSV.c.volume)
result = query.all()
data = pd.DataFrame(result, columns=['name', 'volume'])

data = data.sort_values(by='volume')
# Out:
# 2023-09-11 10:42:35,942 INFO sqlalchemy.engine.Engine SELECT `CombinedCSV`.name AS `CombinedCSV_name`, `CombinedCSV`.volume AS `CombinedCSV_volume`
# FROM `CombinedCSV`
# 2023-09-11 10:42:35,943 INFO sqlalchemy.engine.Engine [generated in 0.00491s] {}

# %%
def remove_outliers(data, column, threshold=1.5):
    q75, q25 = np.percentile(data[column], [75 ,25])
    iqr = q75 - q25
    lower_bound = q25 - (threshold * iqr)
    upper_bound = q75 + (threshold * iqr)
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
df_cleaned = remove_outliers(data, 'volume')

selected_names = random.sample(df_cleaned['name'].tolist(), 40)

means = []
for name in selected_names:
    name_mean = (
        session.query(func.avg(CombinedCSV.c.volume).label('mean_volume'))
        .filter(CombinedCSV.c.name == name)
        .first()
    )
    means.append(name_mean.mean_volume)
# Out:
# 2023-09-11 10:43:52,421 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,421 INFO sqlalchemy.engine.Engine [generated in 0.00071s] {'name_1': 'Arweave', 'param_1': 1}
# 2023-09-11 10:43:52,466 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,466 INFO sqlalchemy.engine.Engine [cached since 0.04585s ago] {'name_1': 'Dash', 'param_1': 1}
# 2023-09-11 10:43:52,497 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,497 INFO sqlalchemy.engine.Engine [cached since 0.07658s ago] {'name_1': 'Stargate Finance', 'param_1': 1}
# 2023-09-11 10:43:52,522 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,523 INFO sqlalchemy.engine.Engine [cached since 0.1023s ago] {'name_1': 'TrueUSD', 'param_1': 1}
# 2023-09-11 10:43:52,544 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,544 INFO sqlalchemy.engine.Engine [cached since 0.1239s ago] {'name_1': 'Osmosis', 'param_1': 1}
# 2023-09-11 10:43:52,563 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,564 INFO sqlalchemy.engine.Engine [cached since 0.1432s ago] {'name_1': 'Osmosis', 'param_1': 1}
# 2023-09-11 10:43:52,584 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,584 INFO sqlalchemy.engine.Engine [cached since 0.1637s ago] {'name_1': 'Ocean Protocol', 'param_1': 1}
# 2023-09-11 10:43:52,604 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,604 INFO sqlalchemy.engine.Engine [cached since 0.1835s ago] {'name_1': 'Fetch.ai', 'param_1': 1}
# 2023-09-11 10:43:52,624 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,625 INFO sqlalchemy.engine.Engine [cached since 0.2042s ago] {'name_1': 'Gala', 'param_1': 1}
# 2023-09-11 10:43:52,644 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,645 INFO sqlalchemy.engine.Engine [cached since 0.2242s ago] {'name_1': 'Lido DAO', 'param_1': 1}
# 2023-09-11 10:43:52,664 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,665 INFO sqlalchemy.engine.Engine [cached since 0.2441s ago] {'name_1': 'Galxe', 'param_1': 1}
# 2023-09-11 10:43:52,684 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,684 INFO sqlalchemy.engine.Engine [cached since 0.2634s ago] {'name_1': 'Synthetix', 'param_1': 1}
# 2023-09-11 10:43:52,703 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,703 INFO sqlalchemy.engine.Engine [cached since 0.2828s ago] {'name_1': 'GMX', 'param_1': 1}
# 2023-09-11 10:43:52,722 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,723 INFO sqlalchemy.engine.Engine [cached since 0.3022s ago] {'name_1': 'The Graph', 'param_1': 1}
# 2023-09-11 10:43:52,742 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,742 INFO sqlalchemy.engine.Engine [cached since 0.3219s ago] {'name_1': 'Bone ShibaSwap', 'param_1': 1}
# 2023-09-11 10:43:52,761 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,762 INFO sqlalchemy.engine.Engine [cached since 0.3412s ago] {'name_1': 'Zcash', 'param_1': 1}
# 2023-09-11 10:43:52,781 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,781 INFO sqlalchemy.engine.Engine [cached since 0.3607s ago] {'name_1': 'Livepeer', 'param_1': 1}
# 2023-09-11 10:43:52,801 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,801 INFO sqlalchemy.engine.Engine [cached since 0.3806s ago] {'name_1': 'VeChain', 'param_1': 1}
# 2023-09-11 10:43:52,820 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,820 INFO sqlalchemy.engine.Engine [cached since 0.3998s ago] {'name_1': 'Aragon', 'param_1': 1}
# 2023-09-11 10:43:52,840 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,840 INFO sqlalchemy.engine.Engine [cached since 0.4199s ago] {'name_1': 'Bone ShibaSwap', 'param_1': 1}
# 2023-09-11 10:43:52,860 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,860 INFO sqlalchemy.engine.Engine [cached since 0.4395s ago] {'name_1': 'JUST', 'param_1': 1}
# 2023-09-11 10:43:52,879 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,879 INFO sqlalchemy.engine.Engine [cached since 0.4588s ago] {'name_1': 'SKALE', 'param_1': 1}
# 2023-09-11 10:43:52,898 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,899 INFO sqlalchemy.engine.Engine [cached since 0.4783s ago] {'name_1': 'Aragon', 'param_1': 1}
# 2023-09-11 10:43:52,918 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,919 INFO sqlalchemy.engine.Engine [cached since 0.4982s ago] {'name_1': 'Storj', 'param_1': 1}
# 2023-09-11 10:43:52,938 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,938 INFO sqlalchemy.engine.Engine [cached since 0.5181s ago] {'name_1': 'Hedera', 'param_1': 1}
# 2023-09-11 10:43:52,958 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,958 INFO sqlalchemy.engine.Engine [cached since 0.5377s ago] {'name_1': 'ssv.network', 'param_1': 1}
# 2023-09-11 10:43:52,977 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,977 INFO sqlalchemy.engine.Engine [cached since 0.5569s ago] {'name_1': 'Ethereum Classic', 'param_1': 1}
# 2023-09-11 10:43:52,996 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:52,996 INFO sqlalchemy.engine.Engine [cached since 0.576s ago] {'name_1': 'Filecoin', 'param_1': 1}
# 2023-09-11 10:43:53,015 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,015 INFO sqlalchemy.engine.Engine [cached since 0.595s ago] {'name_1': 'Basic Attention Token', 'param_1': 1}
# 2023-09-11 10:43:53,034 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,035 INFO sqlalchemy.engine.Engine [cached since 0.6143s ago] {'name_1': 'Siacoin', 'param_1': 1}
# 2023-09-11 10:43:53,055 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,056 INFO sqlalchemy.engine.Engine [cached since 0.6352s ago] {'name_1': 'Neo', 'param_1': 1}
# 2023-09-11 10:43:53,075 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,075 INFO sqlalchemy.engine.Engine [cached since 0.6545s ago] {'name_1': 'Golem', 'param_1': 1}
# 2023-09-11 10:43:53,093 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,094 INFO sqlalchemy.engine.Engine [cached since 0.6732s ago] {'name_1': 'TomoChain', 'param_1': 1}
# 2023-09-11 10:43:53,112 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,112 INFO sqlalchemy.engine.Engine [cached since 0.692s ago] {'name_1': 'Chia', 'param_1': 1}
# 2023-09-11 10:43:53,131 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,131 INFO sqlalchemy.engine.Engine [cached since 0.7109s ago] {'name_1': 'Holo', 'param_1': 1}
# 2023-09-11 10:43:53,150 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,151 INFO sqlalchemy.engine.Engine [cached since 0.7302s ago] {'name_1': 'Hive', 'param_1': 1}
# 2023-09-11 10:43:53,170 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,170 INFO sqlalchemy.engine.Engine [cached since 0.7496s ago] {'name_1': 'Immutable', 'param_1': 1}
# 2023-09-11 10:43:53,189 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,189 INFO sqlalchemy.engine.Engine [cached since 0.7692s ago] {'name_1': 'SingularityNET', 'param_1': 1}
# 2023-09-11 10:43:53,208 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,209 INFO sqlalchemy.engine.Engine [cached since 0.7883s ago] {'name_1': 'Bone ShibaSwap', 'param_1': 1}
# 2023-09-11 10:43:53,227 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS mean_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:43:53,227 INFO sqlalchemy.engine.Engine [cached since 0.8071s ago] {'name_1': 'UniBot', 'param_1': 1}

# %%
overall_mean = np.mean(means)

standard_error = np.std(means) / np.sqrt(len(means))
confidence_level = 0.98

z_score = stats.norm.ppf((1 + confidence_level) / 2)

margin_of_error = z_score * standard_error

confidence_interval = (overall_mean - margin_of_error, overall_mean + margin_of_error)

for i, name in enumerate(selected_names):
    print(f"Name {i + 1}: {name} - Mean Volume: {means[i]}")

print(f"Overall Mean of Means: {overall_mean}")
print(f"98% Confidence Interval for Trading Volume: {confidence_interval}")
# Out:
# Name 1: Arweave - Mean Volume: 22035674.53021977
# Name 2: Dash - Mean Volume: 73749513.18846157
# Name 3: Stargate Finance - Mean Volume: 26005357.68156593
# Name 4: TrueUSD - Mean Volume: 802642762.982802
# Name 5: Osmosis - Mean Volume: 12022034.690934066
# Name 6: Osmosis - Mean Volume: 12022034.690934066
# Name 7: Ocean Protocol - Mean Volume: 27734370.190741763
# Name 8: Fetch.ai - Mean Volume: 52159402.77978024
# Name 9: Gala - Mean Volume: 141368595.84923074
# Name 10: Lido DAO - Mean Volume: 87595129.16013743
# Name 11: Galxe - Mean Volume: 20741623.1298077
# Name 12: Synthetix - Mean Volume: 48727435.52063185
# Name 13: GMX - Mean Volume: 28596386.065219793
# Name 14: The Graph - Mean Volume: 55055944.224752754
# Name 15: Bone ShibaSwap - Mean Volume: 9304986.441620875
# Name 16: Zcash - Mean Volume: 41929469.98796703
# Name 17: Livepeer - Mean Volume: 13197406.875851652
# Name 18: VeChain - Mean Volume: 49270870.36914835
# Name 19: Aragon - Mean Volume: 12745041.069038464
# Name 20: Bone ShibaSwap - Mean Volume: 9304986.441620875
# Name 21: JUST - Mean Volume: 28606924.88607143
# Name 22: SKALE - Mean Volume: 10887593.083461532
# Name 23: Aragon - Mean Volume: 12745041.069038464
# Name 24: Storj - Mean Volume: 26577150.22486265
# Name 25: Hedera - Mean Volume: 46314408.9509616
# Name 26: ssv.network - Mean Volume: 15604253.994972518
# Name 27: Ethereum Classic - Mean Volume: 267962357.34260985
# Name 28: Filecoin - Mean Volume: 193664613.14233515
# Name 29: Basic Attention Token - Mean Volume: 29954902.130439565
# Name 30: Siacoin - Mean Volume: 9856896.01217033
# Name 31: Neo - Mean Volume: 49929222.48607141
# Name 32: Golem - Mean Volume: 13425041.59868132
# Name 33: TomoChain - Mean Volume: 11216245.308324173
# Name 34: Chia - Mean Volume: 5623341.133324175
# Name 35: Holo - Mean Volume: 18690698.05788461
# Name 36: Hive - Mean Volume: 13116432.002719777
# Name 37: Immutable - Mean Volume: 29195519.71513734
# Name 38: SingularityNET - Mean Volume: 58781650.52173075
# Name 39: Bone ShibaSwap - Mean Volume: 9304986.441620875
# Name 40: UniBot - Mean Volume: 7854767.780256407
# Overall Mean of Means: 60138026.793828525
# 98% Confidence Interval for Trading Volume: (12488158.054442078, 107787895.53321497)

# %% [markdown]
# <h2 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمون فرض
# </font>
# </h2>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمون فرض اول
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# شرکت کوئرا شغل پاره‌وقتی را به شما پیشنهاد داده و ۲ حق انتخاب برای روزهای کاری به شما داده است. انتخاب اول، روزهای چهارشنبه تا شنبه و انتخاب دوم روزهای یکشنبه تا چهارشنبه می‌باشد. از آن‌جا که شما علاوه بر فعالیت‌های کاری در حوزه‌ی تخصصی خود، به خرید و فروش رمز ارز نیز مشغول هستید، تصمیم می‌گیرید یک مطالعه‌ی آماری بر روند بازار رمزارزها داشته باشید تا روزهای پویا و متلاطم‌تر بازار را از دست ندهید. بدین منظور می‌خواهید میانگین میزان تغییر قیمت رمزارز‌ها در روزهای پنج‌شنبه، جمعه و شنبه را با روزهای یکشنبه، دوشنبه و سه‌شنبه مقایسه کنید. آیا با این شاخص انتخاب شده، تفاوت فاحشی میان دو انتخاب ممکن برای روزهای کاری وجود دارد؟ در صورت مثبت بودن پاسخ، انتخاب شما چه روز‌هایی است؟
# </font>
# </p>

# %%
#coins['timestamp'] = coins['timestamp'].apply(pd.to_datetime)
weekday_difs = np.zeros(0)
offday_difs = np.zeros(0)
print(weekday_difs.shape)
for coin in coins:
    days = coin['timestamp'].apply(pd.to_datetime).dt.day_name()
    days_week = days.isin(['Sunday','Monday','Tuesday'])
    days_off = days.isin(['Thursday', 'Friday', 'Saturday'])
    dif = coin['close'] - coin['open']
    weekdays = dif.loc[days_week]
    offdays = dif.loc[days_off]
    weekday_difs = np.append(weekday_difs, np.array(weekdays))
    offday_difs = np.append(offday_difs, np.array(offdays))
# Out:
# (0,)

# %%
#weekday_difs = np.array(weekday_difs, dtype=object)
print(weekday_difs.shape, offday_difs.shape)
# Out:
# (29746,) (29759,)

# %%
fig , ax = plt.subplots(figsize= (8, 7))
ax.hist(offday_difs, range=(-0.25,0.25), bins=250)
fig.tight_layout()

# %%
min_days = min(weekday_difs.shape[0], offday_difs.shape[0])
ttest_week = np.random.choice(weekday_difs, min_days)
ttest_off = np.random.choice(offday_difs, min_days)

# %%
t_stat, p_value = stats.ttest_rel(ttest_week, ttest_off, alternative='two-sided')
print("t statistics = ",t_stat)
print("p-value = ", p_value)
if p_value > 0.05:
    print("They are NOT significantly different")
else:
    print("They are significantly different")
# Out:
# t statistics =  2.0759954981193514
# p-value =  0.03790293626438201
# They are Not significantly different

# %%
t_stat, p_value = stats.ttest_rel(ttest_week, ttest_off, alternative='less')
print("t statistics = ",t_stat)
print("p-value = ", p_value)
if p_value < 0.05:
    print("They are significantly different and ttest_week < ttest_off")
# Out:
# t statistics =  2.0759954981193514
# p-value =  0.9810485318678089

# %%
t_stat, p_value = stats.ttest_rel(ttest_week, ttest_off, alternative='greater')
print("t statistics = ",t_stat)
print("p-value = ", p_value)
if p_value < 0.05:
    print("They are significantly different and ttest_week > ttest_off")
# Out:
# t statistics =  2.0759954981193514
# p-value =  0.018951468132191004
# They are significantly different and ttest_week > ttest_off

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمون فرض دوم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# معمولاً افرادی که تازه وارد بازار رمزارز می‌شوند، مایل به سرمایه‌‌گذاری در رمزارزهای بسیار معروف هستند و از طرفی دیگر برخی افراد ریسک‌پذیری پایینی دارند و تمایل دارند در رمزارزهایی با تغییرات کم‌تر نسبت به دیگر رمزارزها سرمایه‌گذاری کنند، لذا به نظر می‌رسد بیشتر معاملات بازار بین معروف‌ترین و باثبات‌ترین رمزارزهای بازار باشد. اکنون می‌خواهیم بررسی کنیم که چه میزان از معاملات روزانه بازار مربوط به این رمزارزهاست. برای این کار سه رمز ارز 'Bitcoin', 'Ethereum', 'Tether USDt' را در نظر بگیرید و بررسی کنید آیا این ادعای زیر صحیح است یا نه؟
# "میانگین حجم معاملات روزانه‌ی  'Bitcoin' ،'Ethereum' و  'Tether USDt'  به‌شدت بیشتر از میانگین حجم معاملات روزانه باقی رمزارزهاست."
#
# </font>
# </p>

# %%
meta = MetaData()

csv4 = Table(
    'CombinedCSV',
    meta,
    Column('name', String(255), primary_key=True),
    Column('time_open', String(255)),
    Column('time_close', String(255)),
    Column('time_high', String(255)),
    Column('time_low', String(255)),
    Column('open', Float),
    Column('high', Float),
    Column('low', Float),
    Column('close', Float),
    Column('volume', Float),
    Column('market_cap', Float),
    Column('timestamp', String(255))
)

Session = sessionmaker(bind=engine)
session = Session()

# %%
bitcoin_volume = (
    session.query(func.avg(CombinedCSV.c.volume).label('avg_volume'))
    .filter(CombinedCSV.c.name == 'Bitcoin')
    .first()
).avg_volume

ethereum_volume = (
    session.query(func.avg(CombinedCSV.c.volume).label('avg_volume'))
    .filter(CombinedCSV.c.name == 'Ethereum')
    .first()
).avg_volume

tether_volume = (
    session.query(func.avg(CombinedCSV.c.volume).label('avg_volume'))
    .filter(CombinedCSV.c.name == 'Tether USDt')
    .first()
).avg_volume

other_cryptos_volume = (
    session.query(func.avg(CombinedCSV.c.volume).label('avg_volume'))
    .filter(CombinedCSV.c.name.notin_(['Bitcoin', 'Ethereum', 'Tether USDt']))
    .first()
).avg_volume

print(bitcoin_volume)
print(ethereum_volume)
print(tether_volume)
print(other_cryptos_volume)
# Out:
# 2023-09-11 10:49:06,585 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 10:49:06,588 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS avg_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:49:06,588 INFO sqlalchemy.engine.Engine [generated in 0.00043s] {'name_1': 'Bitcoin', 'param_1': 1}
# 2023-09-11 10:49:06,661 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS avg_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:49:06,662 INFO sqlalchemy.engine.Engine [cached since 0.07432s ago] {'name_1': 'Ethereum', 'param_1': 1}
# 2023-09-11 10:49:06,684 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS avg_volume
# FROM `CombinedCSV`
# WHERE `CombinedCSV`.name = %(name_1)s
#  LIMIT %(param_1)s
# 2023-09-11 10:49:06,684 INFO sqlalchemy.engine.Engine [cached since 0.09645s ago] {'name_1': 'Tether USDt', 'param_1': 1}
# 2023-09-11 10:49:06,708 INFO sqlalchemy.engine.Engine SELECT avg(`CombinedCSV`.volume) AS avg_volume
# FROM `CombinedCSV`
# WHERE (`CombinedCSV`.name NOT IN (%(name_1_1)s, %(name_1_2)s, %(name_1_3)s))
#  LIMIT %(param_1)s
# 2023-09-11 10:49:06,708 INFO sqlalchemy.engine.Engine [generated in 0.00082s] {'param_1': 1, 'name_1_1': 'Bitcoin', 'name_1_2': 'Ethereum', 'name_1_3': 'Tether USDt'}
# 22967636871.53174
# 8843689497.181652
# 33149475161.08421
# 124611495.0416076

# %%
if bitcoin_volume > other_cryptos_volume and ethereum_volume > other_cryptos_volume and tether_volume > other_cryptos_volume:
    print("The above claim is CORRECT")
else:
    print("The above claim is INCORRECT")
# Out:
# The above claim is CORRECT

# %% [markdown]
# <h2 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# سوال امتیازی
# </font>
# </h2>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# نوید ادعا می‌کند تغییر قیمت رمز‌ارزها در روزهای تعطیل از یک توزیع نرمال پیروی می‌کند. بررسی کنید این ادعا تا چه اندازه صحیح است. بدین منظور نخست هیستوگرام تغییر قیمت روزانه رمز‌ارزها در روز‌های تعطیل (شنبه و یکشنبه) را رسم نمایید. سپس از آزمون آماری متناسب با مسئله استفاده کرده و نظر خود را در رابطه با این ادعا بیان کنید.
#
# </font>
# </p>

# %%
meta = MetaData()

CombinedCSV = Table(
    'CombinedCSV',
    meta,
    Column('name', String(255), primary_key=True),
    Column('timestamp', String(255)),
    Column('open', Float),
    Column('close', Float),
)

Session = sessionmaker(bind=engine)
session = Session()

# %%
HolidayPriceChanges = (
    session.query(CombinedCSV.c.close - CombinedCSV.c.open).filter(func.dayofweek(CombinedCSV.c.timestamp) >= 6).all()
)

PriceChanges = [change[0] for change in HolidayPriceChanges]
#print(len(PriceChanges))
# Out:
# 2023-09-11 18:17:31,909 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-09-11 18:17:31,910 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 18:17:31,925 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-09-11 18:17:31,925 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 18:17:31,927 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-09-11 18:17:31,928 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-09-11 18:17:31,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-09-11 18:17:31,937 INFO sqlalchemy.engine.Engine SELECT `CombinedCSV`.close - `CombinedCSV`.open AS anon_1
# FROM `CombinedCSV`
# WHERE dayofweek(`CombinedCSV`.timestamp) >= %(dayofweek_1)s
# 2023-09-11 18:17:31,938 INFO sqlalchemy.engine.Engine [generated in 0.00075s] {'dayofweek_1': 6}
# 19835

# %%
fig , ax = plt.subplots(figsize= (15, 7))
ax.hist(PriceChanges, bins=50, alpha=0.5, color='blue', edgecolor='black')
ax.set_xlabel('Daily Price Change')
ax.set_ylabel('Frequency')
ax.set_title('Daily Price Change for Cryptocurrencies on Holidays (Saturday and Sunday)')
plt.show()

# %%
fig , ax = plt.subplots(figsize= (15, 7))
ax.hist(PriceChanges, bins=50,range = (-0.1, 0.1), alpha=0.5, color='blue', edgecolor='black')
ax.set_xlabel('Daily Price Change')
ax.set_ylabel('Frequency')
ax.set_title('Daily Price Change for Cryptocurrencies on Holidays (Saturday and Sunday)')
plt.show()

# %%
N = 5000
sample = random.sample(PriceChanges, N)

# %%
# Performing the Shapiro-Wilk normality test

stat, p = stats.shapiro(sample)
print('p_value: ', p)
if p > 0.05:
    print("The data follows a normal distribution (p > 0.05). Navid's claim may be true.")
else:
    print("The data does not follow a normal distribution (p <= 0.05). Navid's claim may not be true.")
# Out:
# p_value:  0.0
# The data does not follow a normal distribution (p <= 0.05). Navid's claim may not be true.

# %%
#normal test
statistic, pvalue = stats.normaltest(PriceChanges)
if pvalue > 0.05:
    print("The data follows a normal distribution (p > 0.05). Navid's claim may be true.")
else:
    print("The data does not follow a normal distribution (p <= 0.05). Navid's claim may not be true.")
# Out:
# The data does not follow a normal distribution (p <= 0.05). Navid's claim may not be true.
